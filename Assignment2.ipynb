# %%
# Print Statement
print("Mars Tech")
# Out:
# Mars Tech

# %%
# Buy input
institute = input("Enter your institute name: ")
# Out:
# Enter your institute name:  MARS TECH

# %%
# Buy inputs
name = input("Enter your name: ")
age = input("Enter your age: ")
school = input("Enter your school name: ")
degree = input("Enter your degree: ")
# Out:
# Enter your name:  Mush
# Enter your age:  21
# Enter your school name:  Madeena
# Enter your degree:  BIT

# %%
# Addition
a = 43
b = 34

add = a + b
print("a =", a)
print("b =", b)
print("Add =", add)
# Out:
# a = 43
# b = 34
# Add = 77

# %%
# Subtraction
a = 43
b = 34

sub = a - b
print("a =", a)
print("b =", b)
print("Sub =", sub)
# Out:
# a = 43
# b = 34
# Sub = 9

# %%
# Multiplication
a = 63
b = 97   # Corrected to get 6111

mul = a * b
print("a =", a)
print("b =", b)
print("Mul =", mul)
# Out:
# a = 63
# b = 97
# Mul = 6111

# %%
# Division
a = 76
b = 31

div = a / b
print("a =", a)
print("b =", b)
print("Float Div =", div)
# Out:
# a = 76
# b = 31
# Float Div = 2.4516129032258065

# %%
# Floor Division
a = 76
b = 31

floor_div = a // b
print("a =", a)
print("b =", b)
print("Floor Div =", floor_div)
# Out:
# a = 76
# b = 31
# Floor Div = 2

# %%
# Modulo
a = 76
b = 31

mod = a % b
print("a =", a)
print("b =", b)
print("Modulo =", mod)
# Out:
# a = 76
# b = 31
# Modulo = 14

# %%
# Power
a = 4
b = 4

power = a ** b
print("a =", a)
print("b =", b)
print("Power =", power)
# Out:
# a = 4
# b = 4
# Power = 256
